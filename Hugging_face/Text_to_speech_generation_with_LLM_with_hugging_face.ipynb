# %% [markdown]
# <a href="https://colab.research.google.com/github/dsPratik-cyber/gen-ai-final/blob/main/Text_to_speech_generation_with_LLM_with_hugging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio

# %%
import torch
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.cuda.current_device())  # Should return the GPU device index

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
text = "abhijit is bad."

pipe = pipeline("text-to-speech", model="suno/bark-small", device="cuda")

output = pipe(text)

# %%
output
# Out:
# {'audio': array([[ 4.7745509e-04, -6.0503982e-05,  1.3699688e-04, ...,
#           1.0926682e-01,  9.2317641e-02,  8.8722058e-02]], dtype=float32),
#  'sampling_rate': 24000}

# %%
from IPython.display import Audio

Audio(output["audio"], rate=output["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
